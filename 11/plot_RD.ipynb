# %% [markdown]
# # 反応拡散モデルの結果プロット用ノートブック
# 内容は前回のセルオートマトンのプロット用ノートブックと同じ

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

# %%
# 関数の定義
def plot_RD(data, step, height=100):
    """
    data: 反応拡散モデルのの出力結果を読み込んだNumPyの多次元配列
    step: ステップ
    height: 1ステップのサイズ（何列か）
    """
    plt.figure( figsize=(5, 5), dpi=120)
    plt.matshow(data[step*height:(step+1)*height], cmap=plt.cm.gray, fignum=1)
    plt.show()

# %% [markdown]
# ## データの読み込みとプロット

# %%
# データ（rd_u.csv）の読み込み
data = np.genfromtxt("11-2.csv", dtype="float",delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6ab44fa7c29e> in <module>()
#       1 # データ（rd_u.csv）の読み込み
# ----> 2 data = np.genfromtxt("11-2.csv", dtype="float",delimiter=",")
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2012             # Raise an exception ?
#    2013             if invalid_raise:
# -> 2014                 raise ValueError(errmsg)
#    2015             # Issue a warning ?
#    2016             else:
#
# ValueError: Some errors were detected !
#     Line #101 (got 1 columns instead of 100)
#     Line #102 (got 1 columns instead of 100)
#     Line #103 (got 1 columns instead of 100)
#     Line #104 (got 1 columns instead of 100)
#     Line #105 (got 1 columns instead of 100)
#     Line #106 (got 1 columns instead of 100)
#     Line #107 (got 1 columns instead of 100)
#     Line #108 (got 1 columns instead of 100)
#     Line #109 (got 1 columns instead of 100)
#     Line #110 (got 1 columns instead of 100)
#     Line #111 (got 1 columns instead of 100)
#     Line #112 (got 1 columns instead of 100)
#     Line #113 (got 1 columns instead of 100)
#     Line #114 (got 1 columns instead of 100)
#     Line #115 (got 1 columns instead of 100)
#     Line #116 (got 1 columns instead of 100)
#     Line #117 (got 1 columns instead of 100)
#     Line #118 (got 1 columns instead of 100)
#     Line #119 (got 1 columns instead of 100)
#     Line #120 (got 1 columns instead of 100)
#     Line #121 (got 1 columns instead of 100)
#     Line #122 (got 1 columns instead of 100)
#     Line #123 (got 1 columns instead of 100)
#     Line #124 (got 1 columns instead of 100)
#     Line #125 (got 1 columns instead of 100)
#     Line #126 (got 1 columns instead of 100)
#     Line #127 (got 1 columns instead of 100)
#     Line #128 (got 1 columns instead of 100)
#     Line #129 (got 1 columns instead of 100)
#     Line #130 (got 1 columns instead of 100)
#     Line #131 (got 1 columns instead of 100)
#     Line #132 (got 1 columns instead of 100)
#     Line #133 (got 1 columns instead of 100)
#     Line #134 (got 1 columns instead of 100)
#     Line #135 (got 1 columns instead of 100)
#     Line #136 (got 1 columns instead of 100)
#     Line #137 (got 1 columns instead of 100)
#     Line #138 (got 1 columns instead of 100)
#     Line #139 (got 1 columns instead of 100)
#     Line #140 (got 1 columns instead of 100)
#     Line #141 (got 1 columns instead of 100)
#     Line #142 (got 1 columns instead of 100)
#     Line #143 (got 1 columns instead of 100)
#     Line #144 (got 1 columns instead of 100)
#     Line #145 (got 1 columns instead of 100)
#     Line #146 (got 1 columns instead of 100)
#     Line #147 (got 1 columns instead of 100)
#     Line #148 (got 1 columns instead of 100)
#     Line #149 (got 1 columns instead of 100)
#     Line #150 (got 1 columns instead of 100)
#     Line #151 (got 1 columns instead of 100)
#     Line #152 (got 1 columns instead of 100)
#     Line #153 (got 1 columns instead of 100)
#     Line #154 (got 1 columns instead of 100)
#     Line #155 (got 1 columns instead of 100)
#     Line #156 (got 1 columns instead of 100)
#     Line #157 (got 1 columns instead of 100)
#     Line #158 (got 1 columns instead of 100)
#     Line #159 (got 1 columns instead of 100)
#     Line #160 (got 1 columns instead of 100)
#     Line #161 (got 1 columns instead of 100)
#     Line #162 (got 1 columns instead of 100)
#     Line #163 (got 1 columns instead of 100)
#     Line #164 (got 1 columns instead of 100)
#     Line #165 (got 1 columns instead of 100)
#     Line #166 (got 1 columns instead of 100)
#     Line #167 (got 1 columns instead of 100)
#     Line #168 (got 1 columns instead of 100)
#     Line #169 (got 1 columns instead of 100)
#     Line #170 (got 1 columns instead of 100)
#     Line #171 (got 1 columns instead of 100)
#     Line #172 (got 1 columns instead of 100)
#     Line #173 (got 1 columns instead of 100)
#     Line #174 (got 1 columns instead of 100)
#     Line #175 (got 1 columns instead of 100)
#     Line #176 (got 1 columns instead of 100)
#     Line #177 (got 1 columns instead of 100)
#     Line #178 (got 1 columns instead of 100)
#     Line #179 (got 1 columns instead of 100)
#     Line #180 (got 1 columns instead of 100)
#     Line #181 (got 1 columns instead of 100)
#     Line #182 (got 1 columns instead of 100)
#     Line #183 (got 1 columns instead of 100)
#     Line #184 (got 1 columns instead of 100)
#     Line #185 (got 1 columns instead of 100)
#     Line #186 (got 1 columns instead of 100)
#     Line #187 (got 1 columns instead of 100)
#     Line #188 (got 1 columns instead of 100)
#     Line #189 (got 1 columns instead of 100)
#     Line #190 (got 1 columns instead of 100)
#     Line #191 (got 1 columns instead of 100)
#     Line #192 (got 1 columns instead of 100)
#     Line #193 (got 1 columns instead of 100)
#     Line #194 (got 1 columns instead of 100)
#     Line #195 (got 1 columns instead of 100)
#     Line #196 (got 1 columns instead of 100)
#     Line #197 (got 1 columns instead of 100)
#     Line #198 (got 1 columns instead of 100)
#     Line #199 (got 1 columns instead of 100)
#     Line #200 (got 1 columns instead of 100)
#     Line #201 (got 1 columns instead of 100)
#     Line #202 (got 1 columns instead of 100)
#     Line #203 (got 1 columns instead of 100)
#     Line #204 (got 1 columns instead of 100)
#     Line #205 (got 1 columns instead of 100)
#     Line #206 (got 1 columns instead of 100)
#     Line #207 (got 1 columns instead of 100)
#     Line #208 (got 1 columns instead of 100)
#     Line #209 (got 1 columns instead of 100)
#     Line #210 (got 1 columns instead of 100)
#     Line #211 (got 1 columns instead of 100)
#     Line #212 (got 1 columns instead of 100)
#     Line #213 (got 1 columns instead of 100)
#     Line #214 (got 1 columns instead of 100)
#     Line #215 (got 1 columns instead of 100)
#     Line #216 (got 1 columns instead of 100)
#     Line #217 (got 1 columns instead of 100)
#     Line #218 (got 1 columns instead of 100)
#     Line #219 (got 1 columns instead of 100)
#     Line #220 (got 1 columns instead of 100)
#     Line #221 (got 1 columns instead of 100)
#     Line #222 (got 1 columns instead of 100)
#     Line #223 (got 1 columns instead of 100)
#     Line #224 (got 1 columns instead of 100)
#     Line #225 (got 1 columns instead of 100)
#     Line #226 (got 1 columns instead of 100)
#     Line #227 (got 1 columns instead of 100)
#     Line #228 (got 1 columns instead of 100)
#     Line #229 (got 1 columns instead of 100)
#     Line #230 (got 1 columns instead of 100)
#     Line #231 (got 1 columns instead of 100)
#     Line #232 (got 1 columns instead of 100)
#     Line #233 (got 1 columns instead of 100)
#     Line #234 (got 1 columns instead of 100)
#     Line #235 (got 1 columns instead of 100)
#     Line #236 (got 1 columns instead of 100)
#     Line #237 (got 1 columns instead of 100)
#     Line #238 (got 1 columns instead of 100)
#     Line #239 (got 1 columns instead of 100)
#     Line #240 (got 1 columns instead of 100)
#     Line #241 (got 1 columns instead of 100)
#     Line #242 (got 1 columns instead of 100)
#     Line #243 (got 1 columns instead of 100)
#     Line #244 (got 1 columns instead of 100)
#     Line #245 (got 1 columns instead of 100)
#     Line #246 (got 1 columns instead of 100)
#     Line #247 (got 1 columns instead of 100)
#     Line #248 (got 1 columns instead of 100)
#     Line #249 (got 1 columns instead of 100)
#     Line #250 (got 1 columns instead of 100)
#     Line #251 (got 1 columns instead of 100)
#     Line #252 (got 1 columns instead of 100)
#     Line #253 (got 1 columns instead of 100)
#     Line #254 (got 1 columns instead of 100)
#     Line #255 (got 1 columns instead of 100)
#     Line #256 (got 1 columns instead of 100)
#     Line #257 (got 1 columns instead of 100)
#     Line #258 (got 1 columns instead of 100)
#     Line #259 (got 1 columns instead of 100)
#     Line #260 (got 1 columns instead of 100)
#     Line #261 (got 1 columns instead of 100)
#     Line #262 (got 1 columns instead of 100)
#     Line #263 (got 1 columns instead of 100)
#     Line #264 (got 1 columns instead of 100)
#     Line #265 (got 1 columns instead of 100)
#     Line #266 (got 1 columns instead of 100)
#     Line #267 (got 1 columns instead of 100)
#     Line #268 (got 1 columns instead of 100)
#     Line #269 (got 1 columns instead of 100)
#     Line #270 (got 1 columns instead of 100)
#     Line #271 (got 1 columns instead of 100)
#     Line #272 (got 1 columns instead of 100)
#     Line #273 (got 1 columns instead of 100)
#     Line #274 (got 1 columns instead of 100)
#     Line #275 (got 1 columns instead of 100)
#     Line #276 (got 1 columns instead of 100)
#     Line #277 (got 1 columns instead of 100)
#     Line #278 (got 1 columns instead of 100)
#     Line #279 (got 1 columns instead of 100)
#     Line #280 (got 1 columns instead of 100)
#     Line #281 (got 1 columns instead of 100)
#     Line #282 (got 1 columns instead of 100)
#     Line #283 (got 1 columns instead of 100)
#     Line #284 (got 1 columns instead of 100)
#     Line #285 (got 1 columns instead of 100)
#     Line #286 (got 1 columns instead of 100)
#     Line #287 (got 1 columns instead of 100)
#     Line #288 (got 1 columns instead of 100)
#     Line #289 (got 1 columns instead of 100)
#     Line #290 (got 1 columns instead of 100)
#     Line #291 (got 1 columns instead of 100)
#     Line #292 (got 1 columns instead of 100)
#     Line #293 (got 1 columns instead of 100)
#     Line #294 (got 1 columns instead of 100)
#     Line #295 (got 1 columns instead of 100)
#     Line #296 (got 1 columns instead of 100)
#     Line #297 (got 1 columns instead of 100)
#     Line #298 (got 1 columns instead of 100)
#     Line #299 (got 1 columns instead of 100)
#     Line #300 (got 1 columns instead of 100)
#     Line #301 (got 1 columns instead of 100)
#     Line #302 (got 1 columns instead of 100)
#     Line #303 (got 1 columns instead of 100)
#     Line #304 (got 1 columns instead of 100)
#     Line #305 (got 1 columns instead of 100)
#     Line #306 (got 1 columns instead of 100)
#     Line #307 (got 1 columns instead of 100)
#     Line #308 (got 1 columns instead of 100)
#     Line #309 (got 1 columns instead of 100)
#     Line #310 (got 1 columns instead of 100)
#     Line #311 (got 1 columns instead of 100)
#     Line #312 (got 1 columns instead of 100)
#     Line #313 (got 1 columns instead of 100)
#     Line #314 (got 1 columns instead of 100)
#     Line #315 (got 1 columns instead of 100)
#     Line #316 (got 1 columns instead of 100)
#     Line #317 (got 1 columns instead of 100)
#     Line #318 (got 1 columns instead of 100)
#     Line #319 (got 1 columns instead of 100)
#     Line #320 (got 1 columns instead of 100)
#     Line #321 (got 1 columns instead of 100)
#     Line #322 (got 1 columns instead of 100)
#     Line #323 (got 1 columns instead of 100)
#     Line #324 (got 1 columns instead of 100)
#     Line #325 (got 1 columns instead of 100)
#     Line #326 (got 1 columns instead of 100)
#     Line #327 (got 1 columns instead of 100)
#     Line #328 (got 1 columns instead of 100)
#     Line #329 (got 1 columns instead of 100)
#     Line #330 (got 1 columns instead of 100)
#     Line #331 (got 1 columns instead of 100)
#     Line #332 (got 1 columns instead of 100)
#     Line #333 (got 1 columns instead of 100)
#     Line #334 (got 1 columns instead of 100)
#     Line #335 (got 1 columns instead of 100)
#     Line #336 (got 1 columns instead of 100)
#     Line #337 (got 1 columns instead of 100)
#     Line #338 (got 1 columns instead of 100)
#     Line #339 (got 1 columns instead of 100)
#     Line #340 (got 1 columns instead of 100)
#     Line #341 (got 1 columns instead of 100)
#     Line #342 (got 1 columns instead of 100)
#     Line #343 (got 1 columns instead of 100)
#     Line #344 (got 1 columns instead of 100)
#     Line #345 (got 1 columns instead of 100)
#     Line #346 (got 1 columns instead of 100)
#     Line #347 (got 1 columns instead of 100)
#     Line #348 (got 1 columns instead of 100)
#     Line #349 (got 1 columns instead of 100)
#     Line #350 (got 1 columns instead of 100)
#     Line #351 (got 1 columns instead of 100)
#     Line #352 (got 1 columns instead of 100)
#     Line #353 (got 1 columns instead of 100)
#     Line #354 (got 1 columns instead of 100)
#     Line #355 (got 1 columns instead of 100)
#     Line #356 (got 1 columns instead of 100)
#     Line #357 (got 1 columns instead of 100)
#     Line #358 (got 1 columns instead of 100)
#     Line #359 (got 1 columns instead of 100)
#     Line #360 (got 1 columns instead of 100)
#     Line #361 (got 1 columns instead of 100)
#     Line #362 (got 1 columns instead of 100)
#     Line #363 (got 1 columns instead of 100)
#     Line #364 (got 1 columns instead of 100)
#     Line #365 (got 1 columns instead of 100)
#     Line #366 (got 1 columns instead of 100)
#     Line #367 (got 1 columns instead of 100)
#     Line #368 (got 1 columns instead of 100)
#     Line #369 (got 1 columns instead of 100)
#     Line #370 (got 1 columns instead of 100)
#     Line #371 (got 1 columns instead of 100)
#     Line #372 (got 1 columns instead of 100)
#     Line #373 (got 1 columns instead of 100)
#     Line #374 (got 1 columns instead of 100)
#     Line #375 (got 1 columns instead of 100)
#     Line #376 (got 1 columns instead of 100)
#     Line #377 (got 1 columns instead of 100)
#     Line #378 (got 1 columns instead of 100)
#     Line #379 (got 1 columns instead of 100)
#     Line #380 (got 1 columns instead of 100)
#     Line #381 (got 1 columns instead of 100)
#     Line #382 (got 1 columns instead of 100)
#     Line #383 (got 1 columns instead of 100)
#     Line #384 (got 1 columns instead of 100)
#     Line #385 (got 1 columns instead of 100)
#     Line #386 (got 1 columns instead of 100)
#     Line #387 (got 1 columns instead of 100)
#     Line #388 (got 1 columns instead of 100)
#     Line #389 (got 1 columns instead of 100)
#     Line #390 (got 1 columns instead of 100)
#     Line #391 (got 1 columns instead of 100)
#     Line #392 (got 1 columns instead of 100)
#     Line #393 (got 1 columns instead of 100)
#     Line #394 (got 1 columns instead of 100)
#     Line #395 (got 1 columns instead of 100)
#     Line #396 (got 1 columns instead of 100)
#     Line #397 (got 1 columns instead of 100)
#     Line #398 (got 1 columns instead of 100)
#     Line #399 (got 1 columns instead of 100)
#     Line #400 (got 1 columns instead of 100)
#     Line #401 (got 1 columns instead of 100)
#     Line #402 (got 1 columns instead of 100)
#     Line #403 (got 1 columns instead of 100)
#     Line #404 (got 1 columns instead of 100)
#     Line #405 (got 1 columns instead of 100)
#     Line #406 (got 1 columns instead of 100)
#     Line #407 (got 1 columns instead of 100)
#     Line #408 (got 1 columns instead of 100)
#     Line #409 (got 1 columns instead of 100)
#     Line #410 (got 1 columns instead of 100)
#     Line #411 (got 1 columns instead of 100)
#     Line #412 (got 1 columns instead of 100)
#     Line #413 (got 1 columns instead of 100)
#     Line #414 (got 1 columns instead of 100)
#     Line #415 (got 1 columns instead of 100)
#     Line #416 (got 1 columns instead of 100)
#     Line #417 (got 1 columns instead of 100)
#     Line #418 (got 1 columns instead of 100)
#     Line #419 (got 1 columns instead of 100)
#     Line #420 (got 1 columns instead of 100)
#     Line #421 (got 1 columns instead of 100)
#     Line #422 (got 1 columns instead of 100)
#     Line #423 (got 1 columns instead of 100)
#     Line #424 (got 1 columns instead of 100)
#     Line #425 (got 1 columns instead of 100)
#     Line #426 (got 1 columns instead of 100)
#     Line #427 (got 1 columns instead of 100)
#     Line #428 (got 1 columns instead of 100)
#     Line #429 (got 1 columns instead of 100)
#     Line #430 (got 1 columns instead of 100)
#     Line #431 (got 1 columns instead of 100)
#     Line #432 (got 1 columns instead of 100)
#     Line #433 (got 1 columns instead of 100)
#     Line #434 (got 1 columns instead of 100)
#     Line #435 (got 1 columns instead of 100)
#     Line #436 (got 1 columns instead of 100)
#     Line #437 (got 1 columns instead of 100)
#     Line #438 (got 1 columns instead of 100)
#     Line #439 (got 1 columns instead of 100)
#     Line #440 (got 1 columns instead of 100)
#     Line #441 (got 1 columns instead of 100)
#     Line #442 (got 1 columns instead of 100)
#     Line #443 (got 1 columns instead of 100)
#     Line #444 (got 1 columns instead of 100)
#     Line #445 (got 1 columns instead of 100)
#     Line #446 (got 1 columns instead of 100)
#     Line #447 (got 1 columns instead of 100)
#     Line #448 (got 1 columns instead of 100)
#     Line #449 (got 1 columns instead of 100)
#     Line #450 (got 1 columns instead of 100)
#     Line #451 (got 1 columns instead of 100)
#     Line #452 (got 1 columns instead of 100)
#     Line #453 (got 1 columns instead of 100)
#     Line #454 (got 1 columns instead of 100)
#     Line #455 (got 1 columns instead of 100)
#     Line #456 (got 1 columns instead of 100)
#     Line #457 (got 1 columns instead of 100)
#     Line #458 (got 1 columns instead of 100)
#     Line #459 (got 1 columns instead of 100)
#     Line #460 (got 1 columns instead of 100)
#     Line #461 (got 1 columns instead of 100)
#     Line #462 (got 1 columns instead of 100)
#     Line #463 (got 1 columns instead of 100)
#     Line #464 (got 1 columns instead of 100)
#     Line #465 (got 1 columns instead of 100)
#     Line #466 (got 1 columns instead of 100)
#     Line #467 (got 1 columns instead of 100)
#     Line #468 (got 1 columns instead of 100)
#     Line #469 (got 1 columns instead of 100)
#     Line #470 (got 1 columns instead of 100)
#     Line #471 (got 1 columns instead of 100)
#     Line #472 (got 1 columns instead of 100)
#     Line #473 (got 1 columns instead of 100)
#     Line #474 (got 1 columns instead of 100)
#     Line #475 (got 1 columns instead of 100)
#     Line #476 (got 1 columns instead of 100)
#     Line #477 (got 1 columns instead of 100)
#     Line #478 (got 1 columns instead of 100)
#     Line #479 (got 1 columns instead of 100)
#     Line #480 (got 1 columns instead of 100)
#     Line #481 (got 1 columns instead of 100)
#     Line #482 (got 1 columns instead of 100)
#     Line #483 (got 1 columns instead of 100)
#     Line #484 (got 1 columns instead of 100)
#     Line #485 (got 1 columns instead of 100)
#     Line #486 (got 1 columns instead of 100)
#     Line #487 (got 1 columns instead of 100)
#     Line #488 (got 1 columns instead of 100)
#     Line #489 (got 1 columns instead of 100)
#     Line #490 (got 1 columns instead of 100)
#     Line #491 (got 1 columns instead of 100)
#     Line #492 (got 1 columns instead of 100)
#     Line #493 (got 1 columns instead of 100)
#     Line #494 (got 1 columns instead of 100)
#     Line #495 (got 1 columns instead of 100)
#     Line #496 (got 1 columns instead of 100)
#     Line #497 (got 1 columns instead of 100)
#     Line #498 (got 1 columns instead of 100)
#     Line #499 (got 1 columns instead of 100)
#     Line #500 (got 1 columns instead of 100)
#     Line #501 (got 1 columns instead of 100)
#     Line #502 (got 1 columns instead of 100)
#     Line #503 (got 1 columns instead of 100)
#     Line #504 (got 1 columns instead of 100)
#     Line #505 (got 1 columns instead of 100)
#     Line #506 (got 1 columns instead of 100)
#     Line #507 (got 1 columns instead of 100)
#     Line #508 (got 1 columns instead of 100)
#     Line #509 (got 1 columns instead of 100)
#     Line #510 (got 1 columns instead of 100)
#     Line #511 (got 1 columns instead of 100)
#     Line #512 (got 1 columns instead of 100)
#     Line #513 (got 1 columns instead of 100)
#     Line #514 (got 1 columns instead of 100)
#     Line #515 (got 1 columns instead of 100)
#     Line #516 (got 1 columns instead of 100)
#     Line #517 (got 1 columns instead of 100)
#     Line #518 (got 1 columns instead of 100)
#     Line #519 (got 1 columns instead of 100)
#     Line #520 (got 1 columns instead of 100)
#     Line #521 (got 1 columns instead of 100)
#     Line #522 (got 1 columns instead of 100)
#     Line #523 (got 1 columns instead of 100)
#     Line #524 (got 1 columns instead of 100)
#     Line #525 (got 1 columns instead of 100)
#     Line #526 (got 1 columns instead of 100)
#     Line #527 (got 1 columns instead of 100)
#     Line #528 (got 1 columns instead of 100)
#     Line #529 (got 1 columns instead of 100)
#     Line #530 (got 1 columns instead of 100)
#     Line #531 (got 1 columns instead of 100)
#     Line #532 (got 1 columns instead of 100)
#     Line #533 (got 1 columns instead of 100)
#     Line #534 (got 1 columns instead of 100)
#     Line #535 (got 1 columns instead of 100)
#     Line #536 (got 1 columns instead of 100)
#     Line #537 (got 1 columns instead of 100)
#     Line #538 (got 1 columns instead of 100)
#     Line #539 (got 1 columns instead of 100)
#     Line #540 (got 1 columns instead of 100)
#     Line #541 (got 1 columns instead of 100)
#     Line #542 (got 1 columns instead of 100)
#     Line #543 (got 1 columns instead of 100)
#     Line #544 (got 1 columns instead of 100)
#     Line #545 (got 1 columns instead of 100)
#     Line #546 (got 1 columns instead of 100)
#     Line #547 (got 1 columns instead of 100)
#     Line #548 (got 1 columns instead of 100)
#     Line #549 (got 1 columns instead of 100)
#     Line #550 (got 1 columns instead of 100)
#     Line #551 (got 1 columns instead of 100)
#     Line #552 (got 1 columns instead of 100)
#     Line #553 (got 1 columns instead of 100)
#     Line #554 (got 1 columns instead of 100)
#     Line #555 (got 1 columns instead of 100)
#     Line #556 (got 1 columns instead of 100)
#     Line #557 (got 1 columns instead of 100)
#     Line #558 (got 1 columns instead of 100)
#     Line #559 (got 1 columns instead of 100)
#     Line #560 (got 1 columns instead of 100)
#     Line #561 (got 1 columns instead of 100)
#     Line #562 (got 1 columns instead of 100)
#     Line #563 (got 1 columns instead of 100)
#     Line #564 (got 1 columns instead of 100)
#     Line #565 (got 1 columns instead of 100)
#     Line #566 (got 1 columns instead of 100)
#     Line #567 (got 1 columns instead of 100)
#     Line #568 (got 1 columns instead of 100)
#     Line #569 (got 1 columns instead of 100)
#     Line #570 (got 1 columns instead of 100)
#     Line #571 (got 1 columns instead of 100)
#     Line #572 (got 1 columns instead of 100)
#     Line #573 (got 1 columns instead of 100)
#     Line #574 (got 1 columns instead of 100)
#     Line #575 (got 1 columns instead of 100)
#     Line #576 (got 1 columns instead of 100)
#     Line #577 (got 1 columns instead of 100)
#     Line #578 (got 1 columns instead of 100)
#     Line #579 (got 1 columns instead of 100)
#     Line #580 (got 1 columns instead of 100)
#     Line #581 (got 1 columns instead of 100)
#     Line #582 (got 1 columns instead of 100)
#     Line #583 (got 1 columns instead of 100)
#     Line #584 (got 1 columns instead of 100)
#     Line #585 (got 1 columns instead of 100)
#     Line #586 (got 1 columns instead of 100)
#     Line #587 (got 1 columns instead of 100)
#     Line #588 (got 1 columns instead of 100)
#     Line #589 (got 1 columns instead of 100)
#     Line #590 (got 1 columns instead of 100)
#     Line #591 (got 1 columns instead of 100)
#     Line #592 (got 1 columns instead of 100)
#     Line #593 (got 1 columns instead of 100)
#     Line #594 (got 1 columns instead of 100)
#     Line #595 (got 1 columns instead of 100)
#     Line #596 (got 1 columns instead of 100)
#     Line #597 (got 1 columns instead of 100)
#     Line #598 (got 1 columns instead of 100)
#     Line #599 (got 1 columns instead of 100)
#     Line #600 (got 1 columns instead of 100)
#     Line #601 (got 1 columns instead of 100)
#     Line #602 (got 1 columns instead of 100)
#     Line #603 (got 1 columns instead of 100)
#     Line #604 (got 1 columns instead of 100)
#     Line #605 (got 1 columns instead of 100)
#     Line #606 (got 1 columns instead of 100)
#     Line #607 (got 1 columns instead of 100)
#     Line #608 (got 1 columns instead of 100)
#     Line #609 (got 1 columns instead of 100)
#     Line #610 (got 1 columns instead of 100)
#     Line #611 (got 1 columns instead of 100)
#     Line #612 (got 1 columns instead of 100)
#     Line #613 (got 1 columns instead of 100)
#     Line #614 (got 1 columns instead of 100)
#     Line #615 (got 1 columns instead of 100)
#     Line #616 (got 1 columns instead of 100)
#     Line #617 (got 1 columns instead of 100)
#     Line #618 (got 1 columns instead of 100)
#     Line #619 (got 1 columns instead of 100)
#     Line #620 (got 1 columns instead of 100)
#     Line #621 (got 1 columns instead of 100)
#     Line #622 (got 1 columns instead of 100)
#     Line #623 (got 1 columns instead of 100)
#     Line #624 (got 1 columns instead of 100)
#     Line #625 (got 1 columns instead of 100)
#     Line #626 (got 1 columns instead of 100)
#     Line #627 (got 1 columns instead of 100)
#     Line #628 (got 1 columns instead of 100)
#     Line #629 (got 1 columns instead of 100)
#     Line #630 (got 1 columns instead of 100)
#     Line #631 (got 1 columns instead of 100)
#     Line #632 (got 1 columns instead of 100)
#     Line #633 (got 1 columns instead of 100)
#     Line #634 (got 1 columns instead of 100)
#     Line #635 (got 1 columns instead of 100)
#     Line #636 (got 1 columns instead of 100)
#     Line #637 (got 1 columns instead of 100)
#     Line #638 (got 1 columns instead of 100)
#     Line #639 (got 1 columns instead of 100)
#     Line #640 (got 1 columns instead of 100)
#     Line #641 (got 1 columns instead of 100)
#     Line #642 (got 1 columns instead of 100)
#     Line #643 (got 1 columns instead of 100)
#     Line #644 (got 1 columns instead of 100)
#     Line #645 (got 1 columns instead of 100)
#     Line #646 (got 1 columns instead of 100)
#     Line #647 (got 1 columns instead of 100)
#     Line #648 (got 1 columns instead of 100)
#     Line #649 (got 1 columns instead of 100)
#     Line #650 (got 1 columns instead of 100)
#     Line #651 (got 1 columns instead of 100)
#     Line #652 (got 1 columns instead of 100)
#     Line #653 (got 1 columns instead of 100)
#     Line #654 (got 1 columns instead of 100)
#     Line #655 (got 1 columns instead of 100)
#     Line #656 (got 1 columns instead of 100)
#     Line #657 (got 1 columns instead of 100)
#     Line #658 (got 1 columns instead of 100)
#     Line #659 (got 1 columns instead of 100)
#     Line #660 (got 1 columns instead of 100)
#     Line #661 (got 1 columns instead of 100)
#     Line #662 (got 1 columns instead of 100)
#     Line #663 (got 1 columns instead of 100)
#     Line #664 (got 1 columns instead of 100)
#     Line #665 (got 1 columns instead of 100)
#     Line #666 (got 1 columns instead of 100)
#     Line #667 (got 1 columns instead of 100)
#     Line #668 (got 1 columns instead of 100)
#     Line #669 (got 1 columns instead of 100)
#     Line #670 (got 1 columns instead of 100)
#     Line #671 (got 1 columns instead of 100)
#     Line #672 (got 1 columns instead of 100)
#     Line #673 (got 1 columns instead of 100)
#     Line #674 (got 1 columns instead of 100)
#     Line #675 (got 1 columns instead of 100)
#     Line #676 (got 1 columns instead of 100)
#     Line #677 (got 1 columns instead of 100)
#     Line #678 (got 1 columns instead of 100)
#     Line #679 (got 1 columns instead of 100)
#     Line #680 (got 1 columns instead of 100)
#     Line #681 (got 1 columns instead of 100)
#     Line #682 (got 1 columns instead of 100)
#     Line #683 (got 1 columns instead of 100)
#     Line #684 (got 1 columns instead of 100)
#     Line #685 (got 1 columns instead of 100)
#     Line #686 (got 1 columns instead of 100)
#     Line #687 (got 1 columns instead of 100)
#     Line #688 (got 1 columns instead of 100)
#     Line #689 (got 1 columns instead of 100)
#     Line #690 (got 1 columns instead of 100)
#     Line #691 (got 1 columns instead of 100)
#     Line #692 (got 1 columns instead of 100)
#     Line #693 (got 1 columns instead of 100)
#     Line #694 (got 1 columns instead of 100)
#     Line #695 (got 1 columns instead of 100)
#     Line #696 (got 1 columns instead of 100)
#     Line #697 (got 1 columns instead of 100)
#     Line #698 (got 1 columns instead of 100)
#     Line #699 (got 1 columns instead of 100)
#     Line #700 (got 1 columns instead of 100)
#     Line #701 (got 1 columns instead of 100)
#     Line #702 (got 1 columns instead of 100)
#     Line #703 (got 1 columns instead of 100)
#     Line #704 (got 1 columns instead of 100)
#     Line #705 (got 1 columns instead of 100)
#     Line #706 (got 1 columns instead of 100)
#     Line #707 (got 1 columns instead of 100)
#     Line #708 (got 1 columns instead of 100)
#     Line #709 (got 1 columns instead of 100)
#     Line #710 (got 1 columns instead of 100)
#     Line #711 (got 1 columns instead of 100)
#     Line #712 (got 1 columns instead of 100)
#     Line #713 (got 1 columns instead of 100)
#     Line #714 (got 1 columns instead of 100)
#     Line #715 (got 1 columns instead of 100)
#     Line #716 (got 1 columns instead of 100)
#     Line #717 (got 1 columns instead of 100)
#     Line #718 (got 1 columns instead of 100)
#     Line #719 (got 1 columns instead of 100)
#     Line #720 (got 1 columns instead of 100)
#     Line #721 (got 1 columns instead of 100)
#     Line #722 (got 1 columns instead of 100)
#     Line #723 (got 1 columns instead of 100)
#     Line #724 (got 1 columns instead of 100)
#     Line #725 (got 1 columns instead of 100)
#     Line #726 (got 1 columns instead of 100)
#     Line #727 (got 1 columns instead of 100)
#     Line #728 (got 1 columns instead of 100)
#     Line #729 (got 1 columns instead of 100)
#     Line #730 (got 1 columns instead of 100)
#     Line #731 (got 1 columns instead of 100)
#     Line #732 (got 1 columns instead of 100)
#     Line #733 (got 1 columns instead of 100)
#     Line #734 (got 1 columns instead of 100)
#     Line #735 (got 1 columns instead of 100)
#     Line #736 (got 1 columns instead of 100)
#     Line #737 (got 1 columns instead of 100)
#     Line #738 (got 1 columns instead of 100)
#     Line #739 (got 1 columns instead of 100)
#     Line #740 (got 1 columns instead of 100)
#     Line #741 (got 1 columns instead of 100)
#     Line #742 (got 1 columns instead of 100)
#     Line #743 (got 1 columns instead of 100)
#     Line #744 (got 1 columns instead of 100)
#     Line #745 (got 1 columns instead of 100)
#     Line #746 (got 1 columns instead of 100)
#     Line #747 (got 1 columns instead of 100)
#     Line #748 (got 1 columns instead of 100)
#     Line #749 (got 1 columns instead of 100)
#     Line #750 (got 1 columns instead of 100)
#     Line #751 (got 1 columns instead of 100)
#     Line #752 (got 1 columns instead of 100)
#     Line #753 (got 1 columns instead of 100)
#     Line #754 (got 1 columns instead of 100)
#     Line #755 (got 1 columns instead of 100)
#     Line #756 (got 1 columns instead of 100)
#     Line #757 (got 1 columns instead of 100)
#     Line #758 (got 1 columns instead of 100)
#     Line #759 (got 1 columns instead of 100)
#     Line #760 (got 1 columns instead of 100)
#     Line #761 (got 1 columns instead of 100)
#     Line #762 (got 1 columns instead of 100)
#     Line #763 (got 1 columns instead of 100)
#     Line #764 (got 1 columns instead of 100)
#     Line #765 (got 1 columns instead of 100)
#     Line #766 (got 1 columns instead of 100)
#     Line #767 (got 1 columns instead of 100)
#     Line #768 (got 1 columns instead of 100)
#     Line #769 (got 1 columns instead of 100)
#     Line #770 (got 1 columns instead of 100)
#     Line #771 (got 1 columns instead of 100)
#     Line #772 (got 1 columns instead of 100)
#     Line #773 (got 1 columns instead of 100)
#     Line #774 (got 1 columns instead of 100)
#     Line #775 (got 1 columns instead of 100)
#     Line #776 (got 1 columns instead of 100)
#     Line #777 (got 1 columns instead of 100)
#     Line #778 (got 1 columns instead of 100)
#     Line #779 (got 1 columns instead of 100)
#     Line #780 (got 1 columns instead of 100)
#     Line #781 (got 1 columns instead of 100)
#     Line #782 (got 1 columns instead of 100)
#     Line #783 (got 1 columns instead of 100)
#     Line #784 (got 1 columns instead of 100)
#     Line #785 (got 1 columns instead of 100)
#     Line #786 (got 1 columns instead of 100)
#     Line #787 (got 1 columns instead of 100)
#     Line #788 (got 1 columns instead of 100)
#     Line #789 (got 1 columns instead of 100)
#     Line #790 (got 1 columns instead of 100)
#     Line #791 (got 1 columns instead of 100)
#     Line #792 (got 1 columns instead of 100)
#     Line #793 (got 1 columns instead of 100)
#     Line #794 (got 1 columns instead of 100)
#     Line #795 (got 1 columns instead of 100)
#     Line #796 (got 1 columns instead of 100)
#     Line #797 (got 1 columns instead of 100)
#     Line #798 (got 1 columns instead of 100)
#     Line #799 (got 1 columns instead of 100)
#     Line #800 (got 1 columns instead of 100)
#     Line #801 (got 1 columns instead of 100)
#     Line #802 (got 1 columns instead of 100)
#     Line #803 (got 1 columns instead of 100)
#     Line #804 (got 1 columns instead of 100)
#     Line #805 (got 1 columns instead of 100)
#     Line #806 (got 1 columns instead of 100)
#     Line #807 (got 1 columns instead of 100)
#     Line #808 (got 1 columns instead of 100)
#     Line #809 (got 1 columns instead of 100)
#     Line #810 (got 1 columns instead of 100)
#     Line #811 (got 1 columns instead of 100)
#     Line #812 (got 1 columns instead of 100)
#     Line #813 (got 1 columns instead of 100)
#     Line #814 (got 1 columns instead of 100)
#     Line #815 (got 1 columns instead of 100)
#     Line #816 (got 1 columns instead of 100)
#     Line #817 (got 1 columns instead of 100)
#     Line #818 (got 1 columns instead of 100)
#     Line #819 (got 1 columns instead of 100)
#     Line #820 (got 1 columns instead of 100)
#     Line #821 (got 1 columns instead of 100)
#     Line #822 (got 1 columns instead of 100)
#     Line #823 (got 1 columns instead of 100)
#     Line #824 (got 1 columns instead of 100)
#     Line #825 (got 1 columns instead of 100)
#     Line #826 (got 1 columns instead of 100)
#     Line #827 (got 1 columns instead of 100)
#     Line #828 (got 1 columns instead of 100)
#     Line #829 (got 1 columns instead of 100)
#     Line #830 (got 1 columns instead of 100)
#     Line #831 (got 1 columns instead of 100)
#     Line #832 (got 1 columns instead of 100)
#     Line #833 (got 1 columns instead of 100)
#     Line #834 (got 1 columns instead of 100)
#     Line #835 (got 1 columns instead of 100)
#     Line #836 (got 1 columns instead of 100)
#     Line #837 (got 1 columns instead of 100)
#     Line #838 (got 1 columns instead of 100)
#     Line #839 (got 1 columns instead of 100)
#     Line #840 (got 1 columns instead of 100)
#     Line #841 (got 1 columns instead of 100)
#     Line #842 (got 1 columns instead of 100)
#     Line #843 (got 1 columns instead of 100)
#     Line #844 (got 1 columns instead of 100)
#     Line #845 (got 1 columns instead of 100)
#     Line #846 (got 1 columns instead of 100)
#     Line #847 (got 1 columns instead of 100)
#     Line #848 (got 1 columns instead of 100)
#     Line #849 (got 1 columns instead of 100)
#     Line #850 (got 1 columns instead of 100)
#     Line #851 (got 1 columns instead of 100)
#     Line #852 (got 1 columns instead of 100)
#     Line #853 (got 1 columns instead of 100)
#     Line #854 (got 1 columns instead of 100)
#     Line #855 (got 1 columns instead of 100)
#     Line #856 (got 1 columns instead of 100)
#     Line #857 (got 1 columns instead of 100)
#     Line #858 (got 1 columns instead of 100)
#     Line #859 (got 1 columns instead of 100)
#     Line #860 (got 1 columns instead of 100)
#     Line #861 (got 1 columns instead of 100)
#     Line #862 (got 1 columns instead of 100)
#     Line #863 (got 1 columns instead of 100)
#     Line #864 (got 1 columns instead of 100)
#     Line #865 (got 1 columns instead of 100)
#     Line #866 (got 1 columns instead of 100)
#     Line #867 (got 1 columns instead of 100)
#     Line #868 (got 1 columns instead of 100)
#     Line #869 (got 1 columns instead of 100)
#     Line #870 (got 1 columns instead of 100)
#     Line #871 (got 1 columns instead of 100)
#     Line #872 (got 1 columns instead of 100)
#     Line #873 (got 1 columns instead of 100)
#     Line #874 (got 1 columns instead of 100)
#     Line #875 (got 1 columns instead of 100)
#     Line #876 (got 1 columns instead of 100)
#     Line #877 (got 1 columns instead of 100)
#     Line #878 (got 1 columns instead of 100)
#     Line #879 (got 1 columns instead of 100)
#     Line #880 (got 1 columns instead of 100)
#     Line #881 (got 1 columns instead of 100)
#     Line #882 (got 1 columns instead of 100)
#     Line #883 (got 1 columns instead of 100)
#     Line #884 (got 1 columns instead of 100)
#     Line #885 (got 1 columns instead of 100)
#     Line #886 (got 1 columns instead of 100)
#     Line #887 (got 1 columns instead of 100)
#     Line #888 (got 1 columns instead of 100)
#     Line #889 (got 1 columns instead of 100)
#     Line #890 (got 1 columns instead of 100)
#     Line #891 (got 1 columns instead of 100)
#     Line #892 (got 1 columns instead of 100)
#     Line #893 (got 1 columns instead of 100)
#     Line #894 (got 1 columns instead of 100)
#     Line #895 (got 1 columns instead of 100)
#     Line #896 (got 1 columns instead of 100)
#     Line #897 (got 1 columns instead of 100)
#     Line #898 (got 1 columns instead of 100)
#     Line #899 (got 1 columns instead of 100)

# %%
# プロット
height=100
interact(lambda step:plot_RD(data, step, height), step=(0,int(len(data)/height)-1,1))
